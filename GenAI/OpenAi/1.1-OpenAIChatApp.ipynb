# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-5.4")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-5.4', 'release_date': '2026-03-05', 'last_updated': '2026-03-05', 'open_weights': False, 'max_input_tokens': 1050000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x00000204C721FB10> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000204C29E5950> root_client=<openai.OpenAI object at 0x00000204C721F750> root_async_client=<openai.AsyncOpenAI object at 0x00000204C29E5BD0> model_name='gpt-5.4' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI is a type of artificial intelligence that creates new content based on patterns it learned from existing data.\n\nExamples of what it can generate:\n- Text\n- Images\n- Music\n- Audio\n- Video\n- Code\n\nFor example:\n- A chatbot writing an email\n- An image model creating a picture from a text prompt\n- A coding assistant generating a function\n\nHow it works, simply:\n1. It is trained on large amounts of data.\n2. It learns patterns, structure, and relationships in that data.\n3. When given a prompt, it produces new content that matches those patterns.\n\nIt does not “think” like a person. It predicts likely outputs based on what it has learned.\n\nCommon examples:\n- ChatGPT for text\n- DALL·E or Midjourney for images\n- GitHub Copilot for code\n- Music generators for songs and sound\n\nWhy it matters:\n- Speeds up creative and routine work\n- Helps brainstorm ideas\n- Automates drafting and content creation\n- Makes tools more conversational and accessible\n\nLimitations:\n- Can make things up or be inaccurate\n- May reflect biases in training data\n- Needs human review for important tasks\n\nIn one sentence: Generative AI is AI that produces new content—like writing, images, audio, or code—from a user’s prompt.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 276, 'prompt_tokens': 12, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-DaDFKiEa3KsE2cvgFKuMduEUCmgIW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ddca1-f211-7030-b93f-da4fb9b923bd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 276, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm  #Due to this chain we can maintains sequence of our custom prompt followed by user's question.

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='LangSmith is a developer platform from the LangChain ecosystem for building, debugging, evaluating, and monitoring LLM applications.\n\n### What it does\n- **Tracing / observability**: Records what your app is doing step by step:\n  - prompts\n  - model calls\n  - tool usage\n  - chains / agents\n  - outputs\n  - latency and errors\n\n- **Debugging**: Lets you inspect individual runs to see why an app behaved a certain way.\n\n- **Evaluation**: Helps you test app quality using datasets and evaluation runs:\n  - compare prompts\n  - compare model versions\n  - measure correctness, relevance, etc.\n\n- **Monitoring**: Track production performance over time, including failures and regressions.\n\n### Why people use it\nIf you’re building an LLM app, it can be hard to answer:\n- Why did the model give this answer?\n- Which prompt version works better?\n- Did the latest change reduce quality?\n- Where is latency coming from?\n\nLangSmith helps answer those questions.\n\n### Typical features\n- End-to-end traces of LLM workflows\n- Dataset creation and test case management\n- Online and offline evaluations\n- Experiment comparison\n- Prompt iteration support\n- Team collaboration for reviewing runs\n\n### Common use cases\n- Debugging a RAG pipeline\n- Evaluating an agent’s tool-calling behavior\n- Comparing GPT-4 vs Claude vs open-source models\n- Testing prompt changes before deployment\n- Monitoring production LLM apps\n\n### How it fits with LangChain\n- It works very naturally with **LangChain**\n- It can also be used with apps that are **not strictly LangChain-based**, depending on how you instrument them\n\n### Simple summary\nThink of **LangSmith** as:\n> **observability + testing + evaluation for LLM apps**\n\nIf you want, I can also give you:\n1. a **simple architecture overview** of LangSmith,\n2. a **LangSmith vs LangChain** explanation, or\n3. a **quick Python example** showing how to use it.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 425, 'prompt_tokens': 32, 'total_tokens': 457, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-DaDNBveKHMHBBkjP5PX8jQitk47RC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ddca9-5dde-7da1-8a1e-222ac5a8bf78-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 32, 'output_tokens': 425, 'total_tokens': 457, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# LangSmith is a developer platform from the LangChain ecosystem for building, debugging, evaluating, and monitoring LLM applications.
#
# ### What it helps with
# - **Tracing:** See every step of an LLM app run, including prompts, model calls, tool usage, retrieval steps, and outputs.
# - **Debugging:** Inspect where failures or bad outputs happen.
# - **Evaluation:** Run datasets and benchmarks against your app or prompt changes.
# - **Monitoring:** Track production behavior, latency, errors, and output quality over time.
# - **Prompt iteration:** Compare prompt versions and model behavior.
# - **Annotation/feedback:** Collect human feedback on outputs for quality improvement.
#
# ### Why people use it
# LLM apps are harder to debug than traditional software because results depend on:
# - prompts
# - model choice
# - retrieval quality
# - tool calling
# - memory/state
# - non-deterministic outputs
#
# LangSmith gives visibility into those parts.
#
# ### Common use cases
# - Testing a RAG pipeline
# - Comparing GPT model versions
# - Finding where an agent loop fails
# - Measuring hallucination or answer quality
# - Observing production chains and agents
#
# ### Key concepts
# - **Runs/Traces:** A record of one execution
# - **Datasets:** Example inputs/expected outputs for evaluation
# - **Evaluators:** Scoring functions, either heuristic, model-based, or human
# - **Projects:** Grouped runs and experiments
# - **Feedback:** Human or automated scores attached to outputs
#
# ### Who typically uses it
# - AI engineers
# - ML platform teams
# - prompt engineers
# - teams building chatbots, agents, RAG apps, and AI workflows
#
# ### In simple terms
# If LangChain helps you **build** LLM apps, LangSmith helps you **understand and improve** them.
#
# If you want, I can also explain:
# 1. **LangSmith vs LangChain**
# 2. **How to use LangSmith with Python**
# 3. **LangSmith for RAG evaluation**
# 4. **LangSmith architecture/workflow**
